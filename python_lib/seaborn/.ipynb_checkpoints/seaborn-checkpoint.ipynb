# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')

# %%
tp=pd.read_csv("D:/Ad_py_lib.csv/matplotlib/tips.csv")

# %%
tp
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
# sns.scatterplot(data=tp,x='total_bill',y='tip')
# sns.scatterplot(data=tp,x='total_bill',y='tip',hue='sex')
sns.scatterplot(data=tp,x='total_bill',y='tip',style='smoker',hue='sex',size='size')
# sns.scatterplot(data=tp,x='total_bill',y='tip',style='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# #### Distrubution plot:Univariant
# 1. KDE:Kernel Density Estimation
# 2. Histogram:

# %%
flt=sns.load_dataset('flights')
flt
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.histplot(data=flt,x='year',y='passengers')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.histplot(data=tp,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.kdeplot(data=tp,x='total_bill',fill=True,hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ### facetplot:work in figure level

# %%
sns.relplot(data=flt,x='month',y='passengers',kind='scatter',col='year',col_wrap=2)
