# %% [markdown]
# ## Numpy Tricks
# np.sort
# Return a sorted copy of an array.
#
# https://numpy.org/doc/stable/reference/generated/numpy.sort.html

# %%
import numpy as np
a = np.random.randint(1,100,15)
a
# Out:
# array([62, 61, 64, 75,  3, 36, 24, 55, 99, 41, 92, 23, 97,  1, 47],
#       dtype=int32)
