# %%
import pandas as pd  
import numpy as np

# %% [markdown]
# * dataframe:Collection of series.
# * To create DataFrame:List,dict,read_csv,etc.

# %%
# using List 
Lt=[['A','B','C','D'],[44,25,74,55]]
Lt
pd.DataFrame(Lt)
pd.DataFrame(Lt,columns=['sum','mon','tue','wed'])
# Out:
#   sum mon tue wed
# 0   A   B   C   D
# 1  44  25  74  55

# %%
#Using Dictionary
Dt={'Name':['amit','rohan','mohan','aman'],'Score':[23,42,54,55]}
Dt
pd.DataFrame(Dt)
# Out:
#     Name  Score
# 0   amit     23
# 1  rohan     42
# 2  mohan     54
# 3   aman     55

# %%
df=pd.read_csv("D:/Ad_py_lib.csv/ml_csv/house.csv")
df
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
import sys
print(sys.getsizeof(df))
# Out:
# 7309351

# %%
df.size
# Out:
# 353412

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# POSTED_BY                 object
# UNDER_CONSTRUCTION         int64
# RERA                       int64
# BHK_NO.                    int64
# BHK_OR_RK                 object
# SQUARE_FT                float64
# READY_TO_MOVE              int64
# RESALE                     int64
# ADDRESS                   object
# LONGITUDE                float64
# LATITUDE                 float64
# TARGET(PRICE_IN_LACS)    float64
# dtype: object

# %%
df.shape
# Out:
# (29451, 12)

# %%
df.columns
# Out:
# Index(['POSTED_BY', 'UNDER_CONSTRUCTION', 'RERA', 'BHK_NO.', 'BHK_OR_RK',
#        'SQUARE_FT', 'READY_TO_MOVE', 'RESALE', 'ADDRESS', 'LONGITUDE',
#        'LATITUDE', 'TARGET(PRICE_IN_LACS)'],
#       dtype='object')

# %%
df['POSTED_BY']
# Out:
# 0         Owner
# 1        Dealer
# 2         Owner
# 3         Owner
# 4        Dealer
#           ...
# 29446     Owner
# 29447     Owner
# 29448    Dealer
# 29449     Owner
# 29450    Dealer
# Name: POSTED_BY, Length: 29451, dtype: object

# %%
type(df['POSTED_BY'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print(df['POSTED_BY'].dtype)
# Out:
# object

# %%
print(df['RERA'].dtype)
# Out:
# int64

# %%
df['RERA'].astype('int32')
df['RERA']=df['RERA'].astype('int32')
print(df['RERA'].dtype)
# Out:
# int32

# %%
import sys
print(sys.getsizeof(df))
# Out:
# 7191547

# %%
# import pandas as pd

# print(df.memory_usage())

# %%
# total = df.memory_usage(deep=True).sum()
# print("Total memory used:", total, "bytes")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29451 entries, 0 to 29450
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   POSTED_BY              29451 non-null  object
#  1   UNDER_CONSTRUCTION     29451 non-null  int64
#  2   RERA                   29451 non-null  int32
#  3   BHK_NO.                29451 non-null  int64
#  4   BHK_OR_RK              29451 non-null  object
#  5   SQUARE_FT              29451 non-null  float64
#  6   READY_TO_MOVE          29451 non-null  int64
#  7   RESALE                 29451 non-null  int64
#  8   ADDRESS                29451 non-null  object
#  9   LONGITUDE              29451 non-null  float64
#  10  LATITUDE               29451 non-null  float64
#  11  TARGET(PRICE_IN_LACS)  29451 non-null  float64
# dtypes: float64(4), int32(1), int64(4), object(3)
# memory usage: 2.6+ MB

# %%
df.describe().T
# Out:
#                          count          mean           std         min  \
# UNDER_CONSTRUCTION     29451.0      0.179756  3.839908e-01    0.000000
# RERA                   29451.0      0.317918  4.656753e-01    0.000000
# BHK_NO.                29451.0      2.392279  8.790913e-01    1.000000
# SQUARE_FT              29451.0  19802.170190  1.901335e+06    3.000000
# READY_TO_MOVE          29451.0      0.820244  3.839908e-01    0.000000
# RESALE                 29451.0      0.929578  2.558613e-01    0.000000
# LONGITUDE              29451.0     21.300255  6.205306e+00  -37.713008
# LATITUDE               29451.0     76.837695  1.055775e+01 -121.761248
# TARGET(PRICE_IN_LACS)  29451.0    142.898746  6.568807e+02    0.250000
#
#                               25%          50%          75%           max
# UNDER_CONSTRUCTION       0.000000     0.000000     0.000000  1.000000e+00
# RERA                     0.000000     0.000000     1.000000  1.000000e+00
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (29451, 12)

# %%
# Return the required values
n=[10,3,53,44,64,35,74,6,3,53,16]
dt=pd.DataFrame(n,columns=['score'])

# %%
dt.duplicated().sum()
# Out:
# np.int64(2)

# %%
dt
# Out:
#     score
# 0      10
# 1       3
# 2      53
# 3      44
# 4      64
# 5      35
# 6      74
# 7       6
# 8       3
# 9      53
# 10     16

# %%
dt['score'].between(10,64)
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# Name: score, dtype: bool

# %%
dt[dt['score'].between(10,64)]
# Out:
#     score
# 0      10
# 2      53
# 3      44
# 4      64
# 5      35
# 9      53
# 10     16

# %%
dt[dt['score'].between(10,64)].count()
# Out:
# score    7
# dtype: int64

# %%
dt[dt['score'].between(10,64)].sum()
# Out:
# score    275
# dtype: int64

# %%
dt.drop_duplicates()#delele last duplicates value.
# Out:
#     score
# 0      10
# 1       3
# 2      53
# 3      44
# 4      64
# 5      35
# 6      74
# 7       6
# 10     16

# %%
dt.drop_duplicates(keep='last')#delele first duplicate value and keep last duplicate value.
# Out:
#     score
# 0      10
# 3      44
# 4      64
# 5      35
# 6      74
# 7       6
# 8       3
# 9      53
# 10     16

# %%
dt.duplicated().sum()
# Out:
# np.int64(2)

# %%
Lt=[23,43,20,50,45,28,54]
dt=pd.DataFrame(Lt)
# print(dt)
(dt==20) | (dt==50) | (dt==23)  #return row booleans(True,False)
# Out:
#        0
# 0   True
# 1  False
# 2   True
# 3   True
# 4  False
# 5  False
# 6  False

# %%
Lt=[23,43,20,50,45,28,54]
dt=pd.DataFrame(Lt)
# print(dt)
dt[(dt==20) | (dt==50) | (dt==23)] #return values with row index
# Out:
#       0
# 0  23.0
# 1   NaN
# 2  20.0
# 3  50.0
# 4   NaN
# 5   NaN
# 6   NaN

# %%
dt[0]
# Out:
# 0    23
# 1    43
# 2    20
# 3    50
# 4    45
# 5    28
# 6    54
# Name: 0, dtype: int64

# %%
dt.isin([20,50,13]) #use build in functions
# Out:
#        0
# 0  False
# 1  False
# 2   True
# 3   True
# 4  False
# 5  False
# 6  False

# %%
dt[dt.isin([20,50,23])]
# Out:
#       0
# 0  23.0
# 1   NaN
# 2  20.0
# 3  50.0
# 4   NaN
# 5   NaN
# 6   NaN

# %%
Lt=[[23,21,np.nan,np.nan],[60,78,93,78]]
df=pd.DataFrame(Lt,columns=['1st','2nd','3rd','4th'])
df
# Out:
#    1st  2nd   3rd   4th
# 0   23   21   NaN   NaN
# 1   60   78  93.0  78.0

# %%
Lt=[[23,21,np.nan,np.nan],[60,78,np.nan,78],[75,np.nan,np.nan]]
df=pd.DataFrame(Lt,columns=['1st','2nd','3rd','4th'])
df

# df.dropna(how='all')  #drop row if all row is NaN.  #dropna has 
# df.dropna()  #drop row if any one row is NaN.
# df.dropna(subset=['1st','4th']) #drop particular row by the help of columns name
# df.dropna(ignore_index=0,subset=['1st','4th'])
# Out:
#    1st   2nd  3rd   4th
# 0   23  21.0  NaN   NaN
# 1   60  78.0  NaN  78.0
# 2   75   NaN  NaN   NaN

# %%
# df.fillna(0,inplace=True) #inplace used used to change the value in original value or dataset.

# %%
# df
# Out:
#    1st   2nd  3rd   4th
# 0   23  21.0  0.0   0.0
# 1   60  78.0  0.0  78.0
# 2   75   0.0  0.0   0.0

# %%
df.fillna(df.mean())
# Out:
#    1st   2nd  3rd   4th
# 0   23  21.0  NaN  78.0
# 1   60  78.0  NaN  78.0
# 2   75  49.5  NaN  78.0

# %%
dc={'Name':['A','B','C','D'],'Score':[53,27,86,43],'Address':['Bhopal','Indore','Delhi','Ujjain']}
df=pd.DataFrame(dc)

# %%
df
# Out:
#   Name  Score Address
# 0    A     53  Bhopal
# 1    B     27  Indore
# 2    C     86   Delhi
# 3    D     43  Ujjain

# %%
df['Name'] # it work on columns.
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# Name: Name, dtype: object

# %%
df.iloc[0] #iloc is used for row indexing extraction,And only for numeric value.
# Out:
# Name            A
# Score          53
# Address    Bhopal
# Name: 0, dtype: object

# %%
df
# Out:
#   Name  Score Address
# 0    A     53  Bhopal
# 1    B     27  Indore
# 2    C     86   Delhi
# 3    D     43  Ujjain

# %%
dc={'Name':['A','B','C','D'],'Score':[53,27,86,43],'Address':['Bhopal','Indore','Delhi','Ujjain']}
ddf=pd.DataFrame(dc)

# %%
ddf
# Out:
#   Name  Score Address
# 0    A     53  Bhopal
# 1    B     27  Indore
# 2    C     86   Delhi
# 3    D     43  Ujjain

# %%
ddf.set_index('Name',inplace=True)

# %%
ddf
# Out:
#       Score Address
# Name
# A        53  Bhopal
# B        27  Indore
# C        86   Delhi
# D        43  Ujjain

# %%
ddf.iloc[0] #iloc for integer values.
# Out:
# Score          53
# Address    Bhopal
# Name: A, dtype: object

# %%
ddf.loc['A']  #loc for str values.
# Out:
# Score          53
# Address    Bhopal
# Name: A, dtype: object

# %%
ddf.reset_index(inplace=True) #return to the last dataset formate.

# %%
ddf
# Out:
#   Name  Score Address
# 0    A     53  Bhopal
# 1    B     27  Indore
# 2    C     86   Delhi
# 3    D     43  Ujjain

# %%
df.iloc[0]
# Out:
# Name            A
# Score          53
# Address    Bhopal
# Name: 0, dtype: object

# %%
df['Name']
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# Name: Name, dtype: object

# %%
l=[19,3,4,2,5,6]
l
# Out:
# [19, 3, 4, 2, 5, 6]

# %%
fq=pd.DataFrame(l)
print(fq.mean())
print(fq.median())
print(fq.var())
print(fq.corr())
# Out:
# 0    6.5
# dtype: float64
# 0    4.5
# dtype: float64
# 0    39.5
# dtype: float64
#      0
# 0  1.0

# %%
fq.describe().T
# Out:
#    count  mean       std  min   25%  50%   75%   max
# 0    6.0   6.5  6.284903  2.0  3.25  4.5  5.75  19.0

# %%
df1=pd.read_excel("C:/Users/sawsu/OneDrive/Desktop/test/Book1.xlsx")

# %%
df1
# Out:
#      day    city weather  temp  windspeed
# 0  45292  bhopal     fog  31.0       10.0
# 1  45324  indore   sunny  22.0        4.0
# 2  45354  bhopal   rainy  32.0       18.0
# 3  45386  bhopal     fog  39.0       16.0
# 4  45417  indore   sunny  30.0        5.0
# 5  45449  bhopal   rainy  35.0       20.0
# 6  45480  ujjain   sunny  38.0        3.0
# 7  45512  ujjain   rainy  32.0       17.0
# 8  45544  ujjain     fog   NaN        NaN

# %%
ct=df1.groupby('city')
# ct=df1.groupby(['city','weather'])

# %%
for c,city in ct:
    print(c)     #combine splite bind
    print(city)
# Out:
# bhopal
#      day    city weather  temp  windspeed
# 0  45292  bhopal     fog  31.0       10.0
# 2  45354  bhopal   rainy  32.0       18.0
# 3  45386  bhopal     fog  39.0       16.0
# 5  45449  bhopal   rainy  35.0       20.0
# indore
#      day    city weather  temp  windspeed
# 1  45324  indore   sunny  22.0        4.0
# 4  45417  indore   sunny  30.0        5.0
# ujjain
#      day    city weather  temp  windspeed
# 6  45480  ujjain   sunny  38.0        3.0
# 7  45512  ujjain   rainy  32.0       17.0
# 8  45544  ujjain     fog   NaN        NaN

# %%
# ct.get_group('bhopal')
ct.get_group('bhopal').apply(min)
# Out:
# day           45292
# city         bhopal
# weather         fog
# temp           23.0
# windspeed      10.0
# dtype: object

# %%
# def cybrom(v):
#     return v > 18
# ct['wind'].apply(cybrom)
# ct.apply(cybrom)

# %%
ct.agg(['sum','min','max'])
# Out:
#            day                         weather                 temp        \
#            sum    min    max               sum    min    max    sum   min
# city
# bhopal  181481  45292  45449  fograinyfograiny    fog  rainy  137.0  31.0
# indore   90741  45324  45417        sunnysunny  sunny  sunny   52.0  22.0
# ujjain  136536  45480  45544     sunnyrainyfog    fog  sunny   70.0  32.0
#
#              windspeed
#          max       sum   min   max
# city
# bhopal  39.0      64.0  10.0  20.0
# indore  30.0       9.0   4.0   5.0
# ujjain  38.0      20.0   3.0  17.0

# %%
len(ct)  #return the length of group mode in grouping.
# Out:
# 3

# %%
# concat 
df2=pd.DataFrame([10,22,15,15,28])   
df3=pd.DataFrame([28,26,23,38,36])
pd.concat([df2,df3],ignore_index=True)
pd.concat([df2,df3],ignore_index=True,axis=1)   #to change dimentionality one D to 2D or more.
# Out:
#     0   1
# 0  10  28
# 1  22  26
# 2  15  23
# 3  15  38
# 4  28  36

# %%
#Multiindex
df1=pd.DataFrame({"Name":["Amit"],"Score":[96]})
df2=pd.DataFrame({'Score':[87],"Address":["Bhopal"]})
# print(df1)
# print(df2)
pd.concat([df1,df2],ignore_index=True) 
# pd.concat([df1,df2],join='inner',ignore_index=True) #add those columns which have two or more time comes in dataset
# Out:
#    Score
# 0     96
# 1     87

# %%
df2=pd.DataFrame([10,22,15,15,28])   
df3=pd.DataFrame([28,26,23,38,36])
pd.concat([df2,df3],keys=["gsdfd","dfdss"])  #multi indexing
# Out:
#           0
# gsdfd 0  10
#       1  22
#       2  15
#       3  15
#       4  28
# dfdss 0  28
#       1  26
#       2  23
#       3  38
#       4  36

# %%
# Merge

# %%
df1=pd.read_csv('D:/Ad_py_lib.csv/pandas_and_numpy/cars1.csv')
df2=pd.read_csv('D:/Ad_py_lib.csv/pandas_and_numpy/cars2.csv')

# %%
df1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %%
df2
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    33.0          4            91         53    1795          17.4     76
# 1    20.0          6           225        100    3651          17.7     76
# 2    18.0          6           250         78    3574          21.0     76
# 3    18.5          6           250        110    3645          16.2     76
# 4    17.5          6           258         95    3193          17.8     76
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                 car
# 0         3         honda civic
# ...

# %%
car1=pd.DataFrame(df1)
car2=pd.DataFrame(df2)
car3=pd.merge(car1,car2,how='outer')

# %%
car3
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0     9.0          8           304        193    4732          18.5     70
# 1    10.0          8           307        200    4376          15.0     70
# 2    10.0          8           360        215    4615          14.0     70
# 3    11.0          8           318        210    4382          13.5     70
# 4    11.0          8           350        180    3664          11.0     73
# ..    ...        ...           ...        ...     ...           ...    ...
# 393  43.4          4            90         48    2335          23.7     80
# 394  44.0          4            97         52    2130          24.6     82
# 395  44.3          4            90         48    2085          21.7     80
# 396  44.6          4            91         67    1850          13.8     80
# 397  46.6          4            86         65    2110          17.9     80
#
# ...

# %%
pd.merge(car1,car2,how='cross')
# Out:
#        mpg_x  cylinders_x  displacement_x horsepower_x  weight_x  \
# 0       18.0            8             307          130      3504
# 1       18.0            8             307          130      3504
# 2       18.0            8             307          130      3504
# 3       18.0            8             307          130      3504
# 4       18.0            8             307          130      3504
# ...      ...          ...             ...          ...       ...
# 39595   29.0            4              90           70      1937
# 39596   29.0            4              90           70      1937
# 39597   29.0            4              90           70      1937
# 39598   29.0            4              90           70      1937
# 39599   29.0            4              90           70      1937
#
#        acceleration_x  model_x  origin_x                      car_x  \
# 0                12.0       70         1  chevrolet chevelle malibu
# ...

# %%
dt1=pd.read_excel("C:/Users/sawsu/OneDrive/Desktop/test/sheet1.xlsx")
dt2=pd.read_excel("C:/Users/sawsu/OneDrive/Desktop/test/sheet2.xlsx")

# %%
dt2
# Out:
#   STUDENID NAME COURSEID
# 0      SO1   AA      C01
# 1      SO2   BB      C02
# 2      SO3   CC      C02
# 3      SO4   DD      C01
# 4      SO5   EE      C01
# 5      SO6   FF      C02
# 6      SO7   GG      C01
# 7      SO8   HH      C02
# 8      SO9   KK    C0100

# %%
dt1
# Out:
#   COURSEID      COURCENAME
# 0      C01       FULLSTACK
# 1      C02            DADS
# 2      C03  CYBER SECURITY

# %%
# Inner Joint

# %%
course=pd.DataFrame(dt1)
student=pd.DataFrame(dt2)

# %%
pd.merge(student,course,how='inner')
# Out:
#   STUDENID NAME COURSEID COURCENAME
# 0      SO1   AA      C01  FULLSTACK
# 1      SO2   BB      C02       DADS
# 2      SO3   CC      C02       DADS
# 3      SO4   DD      C01  FULLSTACK
# 4      SO5   EE      C01  FULLSTACK
# 5      SO6   FF      C02       DADS
# 6      SO7   GG      C01  FULLSTACK
# 7      SO8   HH      C02       DADS

# %%
pd.merge(student,course,how='left',on='COURSEID')
# Out:
#   STUDENID NAME COURSEID COURCENAME
# 0      SO1   AA      C01  FULLSTACK
# 1      SO2   BB      C02       DADS
# 2      SO3   CC      C02       DADS
# 3      SO4   DD      C01  FULLSTACK
# 4      SO5   EE      C01  FULLSTACK
# 5      SO6   FF      C02       DADS
# 6      SO7   GG      C01  FULLSTACK
# 7      SO8   HH      C02       DADS
# 8      SO9   KK    C0100        NaN

# %%
pd.merge(student,course,how='right',on='COURSEID')
# Out:
#   STUDENID NAME COURSEID      COURCENAME
# 0      SO1   AA      C01       FULLSTACK
# 1      SO4   DD      C01       FULLSTACK
# 2      SO5   EE      C01       FULLSTACK
# 3      SO7   GG      C01       FULLSTACK
# 4      SO2   BB      C02            DADS
# 5      SO3   CC      C02            DADS
# 6      SO6   FF      C02            DADS
# 7      SO8   HH      C02            DADS
# 8      NaN  NaN      C03  CYBER SECURITY

# %%
pd.merge(student,course,how='outer',on='COURSEID')
# Out:
#   STUDENID NAME COURSEID      COURCENAME
# 0      SO1   AA      C01       FULLSTACK
# 1      SO4   DD      C01       FULLSTACK
# 2      SO5   EE      C01       FULLSTACK
# 3      SO7   GG      C01       FULLSTACK
# 4      SO9   KK    C0100             NaN
# 5      SO2   BB      C02            DADS
# 6      SO3   CC      C02            DADS
# 7      SO6   FF      C02            DADS
# 8      SO8   HH      C02            DADS
# 9      NaN  NaN      C03  CYBER SECURITY

# %%
pd.merge(student,course,how='cross')
# Out:
#    STUDENID NAME COURSEID_x COURSEID_y      COURCENAME
# 0       SO1   AA        C01        C01       FULLSTACK
# 1       SO1   AA        C01        C02            DADS
# 2       SO1   AA        C01        C03  CYBER SECURITY
# 3       SO2   BB        C02        C01       FULLSTACK
# 4       SO2   BB        C02        C02            DADS
# 5       SO2   BB        C02        C03  CYBER SECURITY
# 6       SO3   CC        C02        C01       FULLSTACK
# 7       SO3   CC        C02        C02            DADS
# 8       SO3   CC        C02        C03  CYBER SECURITY
# 9       SO4   DD        C01        C01       FULLSTACK
# 10      SO4   DD        C01        C02            DADS
# 11      SO4   DD        C01        C03  CYBER SECURITY
# 12      SO5   EE        C01        C01       FULLSTACK
# 13      SO5   EE        C01        C02            DADS
# 14      SO5   EE        C01        C03  CYBER SECURITY
# 15      SO6   FF        C02        C01       FULLSTACK
# ...

# %%
# joint

# %%
import numpy as np 
import pandas as pd  
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df= pd.read_csv("D:/Ad_py_lib.csv/pandas_and_numpy/pandas_data.csv")

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
import sys
sys.getsizeof(df)
# Out:
# 1048842

# %%
df.ndim
# Out:
# 2

# %%
df.duplicated().sum
# Out:
# <bound method Series.sum of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4617    False
# 4618    False
# 4619    False
# 4620    False
# 4621    False
# Length: 4622, dtype: bool>

# %%
df.shape
# Out:
# (4622, 5)

# %%
df.size
# Out:
# 23110

# %%
df.isnull().sum
# Out:
# <bound method DataFrame.sum of       order_id  quantity  item_name  choice_description  item_price
# 0        False     False      False                True       False
# 1        False     False      False               False       False
# 2        False     False      False               False       False
# 3        False     False      False                True       False
# 4        False     False      False               False       False
# ...        ...       ...        ...                 ...         ...
# 4617     False     False      False               False       False
# 4618     False     False      False               False       False
# 4619     False     False      False               False       False
# 4620     False     False      False               False       False
# 4621     False     False      False               False       False
#
# [4622 rows x 5 columns]>

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
df['order_id']=df['order_id'].astype('int32')

# %%
df['quantity']=df['quantity'].astype('int32')

# %%
print(df.dtypes['order_id'])
print(df.dtypes['quantity'])
# Out:
# int32
# int32

# %%
import sys
sys.getsizeof(df)
# Out:
# 1011866

# %%
df.info
# Out:
# <bound method DataFrame.info of       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...
