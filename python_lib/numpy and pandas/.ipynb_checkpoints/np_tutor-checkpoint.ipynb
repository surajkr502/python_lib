# %%
import numpy as np

# %%
a=np.array([1,2,3,4,5,6,7])

# %%
print(a)
print(type(a))
# Out:
# [1 2 3 4 5 6 7]
# <class 'numpy.ndarray'>

# %%
a=np.random.random((3,3))
a=np.round(a*100)
a
# Out:
# array([[77., 46., 65.],
#        [43., 10., 45.],
#        [39., 77., 28.]])
