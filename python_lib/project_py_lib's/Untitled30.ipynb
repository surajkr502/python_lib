# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv("D:/Ad_py_lib.csv/project/california_housing_test.csv")
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df = pd.read_csv("C:/python_pandas/california_housing_test.csv")

# %%
numerical_col = df.select_dtypes(include = ["float64","int64"]).columns

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for column in numerical_cols:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=column, bins=50, kde=False )
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
selected_features = ['median_income', 'total_rooms', 'housing_median_age']

for feature in selected_features:
    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=df, x=feature, y='median_house_value')
    plt.title(f'Scatter plot of {feature} vs median_house_value')
    plt.xlabel(feature)
    plt.ylabel('median_house_value')
    plt.show()

plt.figure(figsize=(12, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='magma', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
plt.figure(figsize=(12, 8))
correlation_matrix = df.corr()
sns.heatmap(df, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
a = 10.20
int(a)
# Out:
# 10

# %%
# Add a categorical column for visualization
df['house_value_category'] = pd.cut(df['median_house_value'],
                                     bins=[0, 100000, 200000, 300000, 400000, 500000,float('inf')],
                                     labels=['<100k', '100k-200k', '200k-300k', '300k-400k', '400k-500k', '>500k'])

# Visualize the distribution of house value categories
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='house_value_category', order=df['house_value_category'].value_counts().index, palette='viridis')
plt.title('Distribution of Median House Value Categories')
plt.xlabel('Median House Value Category')
plt.ylabel('Count')
plt.show()

# Visualize the relationship between median income and median house value, colored by house value category
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='median_income', y='median_house_value', hue='house_value_category',
                size='population', alpha=0.6, sizes=(20, 200), palette='viridis')
plt.title('Median Income vs Median House Value (colored by Category, size by Population)')
plt.xlabel('Median Income')
plt.ylabel('Median House Value')
plt.legend(title='House Value Category')
plt.show()

# Visualize the relationship between geographical location (longitude and latitude) and median house value
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='longitude', y='latitude', hue='median_house_value',
                size='population', alpha=0.9, sizes=(20, 200), palette='viridis')
plt.title('Geographical Distribution of Median House Value')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(title='Median House Value')
plt.show()

# Visualize the distribution of housing median age by house value category using box plots
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, x='house_value_category', y='housing_median_age', order=df['house_value_category'].value_counts().index, palette='viridis')
plt.title('Distribution of Housing Median Age by House Value Category')
plt.xlabel('Median House Value Category')
plt.ylabel('Housing Median Age')
plt.show()

plt.figure(figsize=(12,8))
sns.boxplot(data = a, x = "house _value_category", y = "housing_mdeian_age",order = df['house_value_category'].value_counts().index,palette = 'virdis')
plt.title("distribution of house median age by house value category')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10548\2011146955.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='house_value_category', order=df['house_value_category'].value_counts().index, palette='viridis')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10548\2011146955.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='house_value_category', y='housing_median_age', order=df['house_value_category'].value_counts().index, palette='viridis')

# %%
df['house_value_category'] = pd.cut(df['median_house_value'],
                                     bins=[0, 100000, 200000, 300000, 400000, 500000, float('inf')],
                                     labels=['<100k', '100k-200k', '200k-300k', '300k-400k', '400k-500k', '>500k'])

plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='house_value_category', order=df['house_value_category'].value_counts().index, palette='Purples')
plt.title('Distribution of Median House Value Categories')
plt.xlabel('Median House Value Category')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10548\4030923812.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='house_value_category', order=df['house_value_category'].value_counts().index, palette='Purples')

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='median_income', y='median_house_value', hue='house_value_category',size='population',
     alpha= 0.80,sizes=(20, 200), palette='viridis')
plt.title('Median Income vs Median House Value (colored by Category, size by Population)')
plt.xlabel('Median Income')
plt.legend(title='House Value Category')
plt.ylabel('Median House Value')
plt.show()

# %%
def high():
    for i in range("house_value_category")
plt.scatter(new):

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, x='house_value_category', y='housing_median_age', order=df['house_value_category'].value_counts().index, palette='colorblind')
plt.title('Distribution of Housing Median Age by House Value Category')
plt.xlabel('Median House Value Category')
plt.ylabel('Housing Median Age')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_27896\635517777.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='house_value_category', y='housing_median_age', order=df['house_value_category'].value_counts().index, palette='colorblind')

# %%
import seaborn as sns
print(sns.color_palette().as_hex())              # Current palette
print(sns.palettes.SEABORN_PALETTES.keys())      # Seaborn palettes
       # All registered palettes
# Out:
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
# dict_keys(['deep', 'deep6', 'muted', 'muted6', 'pastel', 'pastel6', 'bright', 'bright6', 'dark', 'dark6', 'colorblind', 'colorblind6'])

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data=df, x='longitude', y='latitude', hue='median_house_value',
                size='population', alpha=0.9, sizes=(20, 200))
plt.title('Geographical Distribution of Median House Value')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
df['house_value_category'] = pd.cut(df['median_house_value'],
                                     bins=[0, 100000, 200000, 300000, 400000, 500000, float('inf')],
                                     labels=['<100k', '100k-200k', '200k-300k', '300k-400k', '400k-500k', '>500k'])

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='house_value_category', order=df['house_value_category'].value_counts().index, palette='coolwarm')
plt.title('Distribution of Median House Value Categories')
plt.xlabel('Median House Value Category')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10548\1132868390.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='house_value_category', order=df['house_value_category'].value_counts().index, palette='coolwarm')

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='median_income', y='median_house_value', hue='house_value_category',
                size='population', alpha=0.6, sizes=(20, 200), palette='viridis')
plt.title('Median Income vs Median House Value (colored by Category, size by Population)')
plt.xlabel('Median Income')
plt.ylabel('Median House Value')
plt.legend(title='House Value Category')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 2
#       1 plt.figure(figsize=(12, 8))
# ----> 2 sns.scatterplot(data=df, x='median_income', y='median_house_value', hue='house_value_category',
#       3                 size='population', alpha=0.6, sizes=(20, 200), palette='viridis')
#       4 plt.title('Median Income vs Median House Value (colored by Category, size by Population)')
#       5 plt.xlabel('Median Income')
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
# ...

# %%
pip install pyttsx3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Visualize the relationship between households and median house value, colored by house value category
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='households', y='median_house_value', hue='house_value_category',
                size='population', alpha=0.6, sizes=(20, 200), palette='viridis')
plt.title('Households vs Median House Value (colored by Category, size by Population)')
plt.xlabel('Households')
plt.ylabel('Median House Value')
plt.legend(title='House Value Category')
plt.show()

# Visualize the relationship between total rooms and median house value, colored by house value category
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='total_rooms', y='median_house_value', hue='house_value_category',
                size='population', alpha=0.6, sizes=(20, 200), palette='viridis')
plt.title('Total Rooms vs Median House Value (colored by Category, size by Population)')
plt.xlabel('Total Rooms')
plt.ylabel('Median House Value')
plt.legend(title='House Value Category')
plt.show()



# Visualize the relationship between median income and population
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='median_income', y='population', alpha=0.6)
plt.title('Scatter plot of Median Income vs Population')
plt.xlabel('Median Income')
plt.ylabel('Population')
plt.show()

# Visualize the relationship between total rooms and total bedrooms, with hue based on house value category
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='total_rooms', y='total_bedrooms', hue='house_value_category', alpha=0.6, palette='viridis')
plt.title('Scatter plot of Total Rooms vs Total Bedrooms (colored by House Value Category)')
plt.xlabel('Total Rooms')
plt.ylabel('Total Bedrooms')
plt.legend(title='House Value Category')
plt.show()

# Visualize the distribution of median income by house value category using a stripplot
plt.figure(figsize=(12, 8))
sns.stripplot(data=df.sample(frac=0.1), x='house_value_category', y='median_income', order=df['house_value_category'].value_counts().index, palette='viridis', alpha=0.6) # Sample to avoid plotting too many points
plt.title('Distribution of Median Income by House Value Category (Strip Plot)')
plt.xlabel('Median House Value Category')
plt.ylabel('Median Income')
plt.show()

# Visualize the distribution of total rooms by house value category using a boxenplot
plt.figure(figsize=(12, 8))
sns.violinplot(data=df, x='house_value_category', y='total_rooms', 
               order=df['house_value_category'].value_counts().index, palette='viridis')
plt.title('Distribution of Total Rooms by House Value Category (Boxen Plot)')
plt.xlabel('Median House Value Category')
plt.ylabel('Total Rooms')
plt.show()

plt.representation():
def merge(new):
    # for delivering thr correlation
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10548\4125091311.py:42: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=df.sample(frac=0.1), x='house_value_category', y='median_income', order=df['house_value_category'].value_counts().index, palette='viridis', alpha=0.6) # Sample to avoid plotting too many points
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10548\4125091311.py:50: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(data=df, x='house_value_category', y='total_rooms', order=df['house_value_category'].value_counts().index, palette='viridis')

# %%
plt.figure(figsize=(12, 8))
sns.stripplot(data=df, x='house_value_category', y='median_income', order=df['house_value_category'].value_counts().index, palette='viridis', alpha=0.6) # Sample to avoid plotting too many points
plt.title('Distribution of Median Income by House Value Category (Strip Plot)')
plt.xlabel('Median House Value Category')
plt.ylabel('Median Income')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10548\189032378.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=df.sample(frac=0.1), x='house_value_category', y='median_income', order=df['house_value_category'].value_counts().index, palette='viridis', alpha=0.6) # Sample to avoid plotting too many points

# %%
# Visualize the distribution of total rooms by house value category using a boxenplot
plt.figure(figsize=(12, 8))
sns.boxenplot(data=df, x='house_value_category', y='total_rooms', order=df['house_value_category'].value_counts().index, palette='viridis')
plt.title('Distribution of Total Rooms by House Value Category (Boxen Plot)')
plt.xlabel('Median House Value Category')
plt.ylabel('Total Rooms')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10548\1360478673.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(data=df, x='house_value_category', y='total_rooms', order=df['house_value_category'].value_counts().index, palette='viridis')

# %%
# Visualize the relationship between households and median house value, colored by house value category
# Visualize the relationship between total rooms and median house value, colored by house value category
# Visualize the relationship between median income and population
# Visualize the relationship between total rooms and total bedrooms, with hue based on house value category
# Visualize the distribution of median income by house value category using a stripplot
# Visualize the distribution of total rooms by house value category using a boxenplot

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(data=df, x='house_value_category', y='total_rooms', order=df['house_value_category'].value_counts().index, palette='viridis')
plt.title('Distribution of Total Rooms by House Value Category (Boxen Plot)')
plt.xlabel('Median House Value Category')
plt.ylabel('Total Rooms')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10548\1167383235.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='house_value_category', y='total_rooms', order=df['house_value_category'].value_counts().index, palette='viridis')

# %%
def model_implifier(new_model):
    new_model define(radar):

# %%
# Visualize the relationship between households and median house value, colored by house value category
# Visualize the relationship between total rooms and median house value, colored by house value category
# Visualize the relationship between median income and population
# Visualize the relationship between total rooms and total bedrooms, with hue based on house value category
# Visualize the distribution of median income by house value category using a stripplot
# Visualize the distribution of total rooms by house value category
