# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv("D:/Ad_py_lib.csv/project/california_housing_test.csv")
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df=pd.read_csv("D:/Ad_py_lib.csv/project/california_housing_test.csv")

# %%
numerical_cols=df.select_dtypes(include=['float64','int64']).columns
for columns in numerical_cols: 
    plt.figure(figsize=(10,6))
    sns.histplot(data=df,x=columns,bins=50,kde=True)
    plt.title(f'distribution of {columns}')
    plt.xlabel(columns)
    plt.ylabel('frequency')
    plt.show()

# %%
selected_features = ['median_income', 'total_rooms', 'housing_median_age']
for feature in selected_features:
    plt.figure(figsize=(10,6))
    sns.scatterplot(data=df,x=feature, y='median_house_value',color='green',marker='^',label='Data Analyse')
    plt.title(f'Scatter plot of (featurer vs median_house_value')
    plt.xlabel(feature)
    plt.ylabel('median_house_value')
    plt.show()
plt.figure(figsize=(12,8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='magma', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
numerical_cols=df.select_dtypes(include=['float64','int64']).columns
for columns in numerical_cols: 
    plt.plot(feature,'median_house_value',color='blue',linestyle='--',linewidth=1,marker='o',label='2025 sales data')
    plt.figure(figsize=(10,6))
    sns.histplot(data=df,x=columns,bins=50,kde=True)
    plt.title(f'distribution of {columns}')
    plt.xlabel(columns)
    plt.ylabel('frequency')
    plt.legend(loc='upper right',fontsize=10)
    plt.grid(color='gray',linestyle=':',linewidth=0.5)
    plt.show()
# plt.figure(figsize=(12,8))
# correlation_matrix = df.corr()
# sns.heatmap(correlation_matrix, annot=True, cmap='magma', fmt=".2f")
# plt.title('Correlation Matrix of Numerical Features')
# plt.show()
# plt.legend(loc='upper right',fontsize=10)
# plt.grid(color='gray',linestyle=':',linewidth=0.5)
# plt.xlim(1,7)
# plt.ylim(0,65000)
# plt.xticks([1,2,3,4,5,6],['M1','M2','M3','M4','M5','M6'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 numerical_cols=df.select_dtypes(include=['float64','int64']).columns
#       2 for columns in numerical_cols:
# ----> 3     plt.plot(feature,'median_house_value',color='blue',linestyle='--',linewidth=1,marker='o',label='2025 sales data')
#       4     plt.figure(figsize=(10,6))
#       5     sns.histplot(data=df,x=columns,bins=50,kde=True)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3829, in plot(scalex, scaley, data, *args, **kwargs)
#    3821 @_copy_docstring_and_deprecators(Axes.plot)
#    3822 def plot(
#    3823     *args: float | ArrayLike | str,
#    (...)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#    3832         scaley=scaley,
# ...
