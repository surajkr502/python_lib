# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
pd.read_csv("D:/Ad_py_lib.csv/pandas_and_numpy/US_Baby_Names.csv")
# Out:
#          Unnamed: 0       Id     Name  Year Gender State  Count
# 0             11349    11350     Emma  2004      F    AK     62
# 1             11350    11351  Madison  2004      F    AK     48
# 2             11351    11352   Hannah  2004      F    AK     46
# 3             11352    11353    Grace  2004      F    AK     44
# 4             11353    11354    Emily  2004      F    AK     41
# ...             ...      ...      ...   ...    ...   ...    ...
# 1016390     5647421  5647422     Seth  2014      M    WY      5
# 1016391     5647422  5647423  Spencer  2014      M    WY      5
# 1016392     5647423  5647424     Tyce  2014      M    WY      5
# 1016393     5647424  5647425   Victor  2014      M    WY      5
# 1016394     5647425  5647426   Waylon  2014      M    WY      5
#
# [1016395 rows x 7 columns]

# %%
df=pd.read_csv("D:/Ad_py_lib.csv/pandas_and_numpy/US_Baby_Names.csv")

# %%
numerical_cols=df.select_dtypes(include=['int64','float64']).columns

# %%
for columns in numerical_cols:
    plt.figure(figsize=(12,8))
    sns.histplot(data=df,x=columns,bins=50,kde=True)
    plt.title(f'distribution by {columns}')
    plt.xlabel(columns)
    plt.ylabel('frequency')
    plt.show()

# %%
selected_categories=['Id','Year']
for categories in selected_categories:
    plt.figure(figsize=(10,8))
    sns.scatterplot(data=df,x=categories,y='Count')
    plt.title(f'scatter plot of {categories} vs Count')
    plt.xlabel(categories)
    plt.ylabel('Count')
    plt.show() 
plt.figure(figsize=(12,8))
correlation_matrix=df.corr(numeric_only=True) 
sns.heatmap(correlation_matrix,annot=True,cmap='Reds',fmt=".2f")
# In Seaborn/Matplotlib, the cmap parameter does not accept arbitrary color names like "red".
# It only accepts colormap names (gradients), such as "magma", "viridis", "coolwarm", "Blues", etc.
# sns.heatmap(correlation_matrix, annot=True,cmap=plt.cm.Reds) 
plt.title('correlation_matrix of numerical categories')
plt.show()
